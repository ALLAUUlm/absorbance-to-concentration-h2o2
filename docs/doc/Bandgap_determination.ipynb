# %% [markdown]
# KPHI_lit = BLPHI4
# date = 20240209

# %%
from sympy import symbols, solve
x = symbols('x')

a0_1 =-631.40547
a0_2 =-0.03863
m_1 =232.06277
m_2 =0.02881
f_x1 = a0_1 + m_1 * x
f_x2 = a0_2 + m_2 * x


# Setze f_x1 = f_x2 und löse nach x
print("\nLösen von f_x1 = f_x2:")
print(f"{a0_1} + {m_1}*x = {a0_2} + {m_2}*x")
x_sol_1_2 = (a0_2 - a0_1) / (m_1 - m_2)
print(f"x = {x_sol_1_2}")
# Out:
# Lösen von f_x1 = f_x2:
# -631.40547 + 232.06277*x = -0.03863 + 0.02881*x
# x = 2.721010493463974

# %% [markdown]
# KPHI_bulk = LN46

# %%
a0_1 =-0.66325
a0_2 =-0.08378
a0_3 =-0.00104
m_1 =0.2531
m_2 =0.03998
m_3 =0.00111
f_x1 = a0_1 + m_1 * x
f_x2 = a0_2 + m_2 * x
f_x3 = a0_3 + m_3 * x


# Setze f_x1 = f_x2 und löse nach x
print("\nLösen von f_x1 = f_x2:")
print(f"{a0_1} + {m_1}*x = {a0_2} + {m_2}*x")
x_sol_1_2 = (a0_2 - a0_1) / (m_1 - m_2)
print(f"x = {x_sol_1_2}")

# Setze f_x2 = f_x3 und löse nach x
print("\nLösen von f_x2 = f_x3:")
print(f"{a0_2} + {m_2}*x = {a0_3} + {m_3}*x")
x_sol_2_3 = (a0_3 - a0_2) / (m_2 - m_3)
print(f"x = {x_sol_2_3}")
# Out:
# Lösen von f_x1 = f_x2:
# -0.66325 + 0.2531*x = -0.08378 + 0.03998*x
# x = 2.71898460960961
#
# Lösen von f_x2 = f_x3:
# -0.08378 + 0.03998*x = -0.00104 + 0.00111*x
# x = 2.128633907898122

# %% [markdown]
# KPHIS_1 = LN55
# date = 0124_1

# %%
a0_1 =-18.26686
a0_2 =-0.31758

m_1 =6.77256
m_2 =0.16493

f_x1 = a0_1 + m_1 * x
f_x2 = a0_2 + m_2 * x


# Setze f_x1 = f_x2 und löse nach x
print("\nLösen von f_x1 = f_x2:")
print(f"{a0_1} + {m_1}*x = {a0_2} + {m_2}*x")
x_sol_1_2 = (a0_2 - a0_1) / (m_1 - m_2)
print(f"x = {x_sol_1_2}")

# Setze f_x2 = f_x3 und löse nach x
print("\nLösen von f_x2 = f_x3:")
print(f"{a0_2} + {m_2}*x = {a0_3} + {m_3}*x")
x_sol_2_3 = (a0_3 - a0_2) / (m_2 - m_3)
print(f"x = {x_sol_2_3}")
# Out:
# Lösen von f_x1 = f_x2:
# -18.26686 + 6.77256*x = -0.31758 + 0.16493*x
# x = 2.7164475008437217
#
# Lösen von f_x2 = f_x3:
# -0.31758 + 0.16493*x = -0.00104 + 0.00111*x
# x = 1.932242705408375

# %% [markdown]
# KPHIS_1 = LN55
# date = unknown
# green

# %%
a0_1 =-30.14305
a0_2 =-0.03836

m_1 =11.05957
m_2 =0.02874

f_x1 = a0_1 + m_1 * x
f_x2 = a0_2 + m_2 * x


# Setze f_x1 = f_x2 und löse nach x
print("\nLösen von f_x1 = f_x2:")
print(f"{a0_1} + {m_1}*x = {a0_2} + {m_2}*x")
x_sol_1_2 = (a0_2 - a0_1) / (m_1 - m_2)
print(f"x = {x_sol_1_2}")
# Out:
# Lösen von f_x1 = f_x2:
# -30.14305 + 11.05957*x = -0.03836 + 0.02874*x
# x = 2.7291409621941414

# %% [markdown]
# KPHIS_3 = LN 31
# date = 0124_1

# %%
a0_1 =-232.86183
a0_2 =-0.65341
m_1 =84.32314
m_2 =0.50269
f_x1 = a0_1 + m_1 * x
f_x2 = a0_2 + m_2 * x

# Setze f_x1 = f_x2 und löse nach x
print("\nLösen von f_x1 = f_x2:")
print(f"{a0_1} + {m_1}*x = {a0_2} + {m_2}*x")
x_sol_1_2 = (a0_2 - a0_1) / (m_1 - m_2)
print(f"x = {x_sol_1_2}")
# Out:
# Lösen von f_x1 = f_x2:
# -232.86183 + 84.32314*x = -0.65341 + 0.50269*x
# x = 2.7703074846293476

# %% [markdown]
# KPHIS_2 = LN 33
# date = 0124_1

# %%
a0_1 =-190.13498
a0_2 =-0.35125
m_1 =69.64972
m_2 =0.2872
f_x1 = a0_1 + m_1 * x
f_x2 = a0_2 + m_2 * x

# Setze f_x1 = f_x2 und löse nach x
print("\nLösen von f_x1 = f_x2:")
print(f"{a0_1} + {m_1}*x = {a0_2} + {m_2}*x")
x_sol_1_2 = (a0_2 - a0_1) / (m_1 - m_2)
print(f"x = {x_sol_1_2}")
# Out:
# Lösen von f_x1 = f_x2:
# -190.13498 + 69.64972*x = -0.35125 + 0.2872*x
# x = 2.7361135379741106

# %% [markdown]
# Ni mit Referenz

# %%
a0_1 =-9.25305E-4
a0_2 =-5.47911E-5
m_1 =4.65271E-4
m_2 =4.09827E-5
f_x1 = a0_1 + m_1 * x
f_x2 = a0_2 + m_2 * x

# Setze f_x1 = f_x2 und löse nach x
print("\nLösen von f_x1 = f_x2:")
print(f"{a0_1} + {m_1}*x = {a0_2} + {m_2}*x")
x_sol_1_2 = (a0_2 - a0_1) / (m_1 - m_2)
print(f"x = {x_sol_1_2}")
# Out:
# Lösen von f_x1 = f_x2:
# -0.000925305 + 0.000465271*x = -5.47911e-05 + 4.09827e-05*x
# x = 2.0517037589770917

# %% [markdown]
# Ni zweiter Peak

# %%
a0_1 =-0.00659
a0_2 =-2.82651E-4
m_1 =0.00172
m_2 =8.58423E-5
f_x1 = a0_1 + m_1 * x
f_x2 = a0_2 + m_2 * x

# Setze f_x1 = f_x2 und löse nach x
print("\nLösen von f_x1 = f_x2:")
print(f"{a0_1} + {m_1}*x = {a0_2} + {m_2}*x")
x_sol_1_2 = (a0_2 - a0_1) / (m_1 - m_2)
print(f"x = {x_sol_1_2}")
# Out:
# Lösen von f_x1 = f_x2:
# -0.00659 + 0.00172*x = -0.000282651 + 8.58423e-05*x
# x = 3.859694202095673

# %% [markdown]
# Ni 1V erster Tiral

# %%
a0_1 =-834.63699
a0_2 =-1.24096
m_1 =263.27673
m_2 =1.07644
f_x1 = a0_1 + m_1 * x
f_x2 = a0_2 + m_2 * x

# Setze f_x1 = f_x2 und löse nach x
print("\nLösen von f_x1 = f_x2:")
print(f"{a0_1} + {m_1}*x = {a0_2} + {m_2}*x")
x_sol_1_2 = (a0_2 - a0_1) / (m_1 - m_2)
print(f"x = {x_sol_1_2}")
# Out:
# Lösen von f_x1 = f_x2:
# -834.63699 + 263.27673*x = -1.24096 + 1.07644*x
# x = 3.1784710459321004

# %% [markdown]
# pures Ni

# %%
a0_1 =-1218.67229
a0_2 =-1.79933
m_1 =382.85835
m_2 =1.46977
f_x1 = a0_1 + m_1 * x
f_x2 = a0_2 + m_2 * x

# Setze f_x1 = f_x2 und löse nach x
print("\nLösen von f_x1 = f_x2:")
print(f"{a0_1} + {m_1}*x = {a0_2} + {m_2}*x")
x_sol_1_2 = (a0_2 - a0_1) / (m_1 - m_2)
print(f"x = {x_sol_1_2}")
# Out:
# Lösen von f_x1 = f_x2:
# -1218.67229 + 382.85835*x = -1.79933 + 1.46977*x
# x = 3.1906381675088435
